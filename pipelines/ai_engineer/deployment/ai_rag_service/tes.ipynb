# %%
import os
from pathlib import Path
from dotenv import load_dotenv

BASE_DIR = Path.cwd().resolve().parents[1]
ENV_PATH = BASE_DIR / '.env'
load_dotenv(dotenv_path=ENV_PATH)

# Define constants for PDF file path
PDF_FILE_PATH = BASE_DIR / "docs" / "RAG_Analysis_Report.pdf"
print(f"PDF file path: {PDF_FILE_PATH}")
# Out:
# PDF file path: /Users/miftahhadiyannoor/Documents/Fashion_Recommendation_Engineer/pipelines/ai_engineer/docs/RAG_Analysis_Report.pdf
