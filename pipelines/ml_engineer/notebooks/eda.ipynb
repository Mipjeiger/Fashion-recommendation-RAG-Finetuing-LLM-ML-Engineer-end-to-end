# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load data from sql loss_profit.db

# %%
# Load database .db from pipelines/data_engineer/database/loss_profit.db
from sqlalchemy import create_engine, text
from pathlib import Path

CURR_DIR = Path.cwd()
ROOT_DIR = CURR_DIR.parent.parent
DB_PATH = ROOT_DIR / 'data_engineer' / 'database' / 'loss_profit_renew.db'

# Load data base .db and check tables
engine = create_engine(f'sqlite:///{DB_PATH}')
with engine.connect() as connection:
    result = connection.execute(text("SELECT name FROM sqlite_master WHERE type='table';"))
    tables = result.fetchall()
    print("Tables in the database:")
    for table in tables:
        print(table[0])

if tables:
    for table_name in tables:
        with engine.connect() as connection:
            query = text(f"SELECT * FROM {table_name[0]}")
            df = pd.read_sql(query, connection)
            print(f"\nData from table '{table_name[0]}':")
            print(f"Database: {df.head()}")
else:
    print("No tables found in the database.")
# Out:
# Tables in the database:
# loss_profit
#
# Data from table 'loss_profit':
# Database:        item_id  purchase_count  view_count   price  stocks     sales  \
# 0  item_000001              56          91  365256     119  20454336
# 1  item_000002              83         212  249729     104  20727507
# 2  item_000003             176         166  276724      97  48703424
# 3  item_000004              63         132  314195     123  19794285
# 4  item_000005               3         506  213034     162    639102
#
#    stock_value_retail profit_status  conversion_rate
# 0            43465464        profit        61.538462
# 1            25971816        profit        39.150943
# 2            26842228        profit       106.024096
# 3            38645985        profit        47.727273
# 4            34511508        profit         0.592885

# %% [markdown]
# ## Database as df -> Transformed database by data_engineer dir
#
# ### - **Added new column on total_revenue, stock_value, profit_status**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   item_id             300000 non-null  object
#  1   purchase_count      300000 non-null  int64
#  2   view_count          300000 non-null  int64
#  3   price               300000 non-null  int64
#  4   stocks              300000 non-null  int64
#  5   sales               300000 non-null  int64
#  6   stock_value_retail  300000 non-null  int64
#  7   profit_status       300000 non-null  object
#  8   conversion_rate     300000 non-null  float64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 20.6+ MB

# %%
df.describe()
# Out:
#        purchase_count     view_count          price         stocks  \
# count   300000.000000  300000.000000  300000.000000  300000.000000
# mean        29.505340     798.099583  275214.493157     100.166573
# std         29.936504     799.071223   85160.601177      58.032946
# min          0.000000       0.000000   53402.000000       0.000000
# 25%          8.000000     228.000000  224457.750000      50.000000
# 50%         20.000000     552.000000  288549.000000     100.000000
# 75%         41.000000    1107.000000  336060.750000     150.000000
# max        348.000000   10367.000000  572572.000000     200.000000
#
#               sales  stock_value_retail  conversion_rate
# count  3.000000e+05        3.000000e+05    300000.000000
# mean   8.118207e+06        2.756189e+07        25.166193
# std    8.973939e+06        1.877912e+07       197.720139
# min    0.000000e+00        0.000000e+00         0.000000
# 25%    2.014958e+06        1.200870e+07         1.164725
# 50%    5.194244e+06        2.433093e+07         3.631961
# 75%    1.104536e+07        4.128084e+07        11.067848
# max    1.443639e+08        1.013616e+08     22200.000000

# %% [markdown]
# ## Feature engineering

# %%
# Fix item_id at the source (run before everything)
NUM_ITEMS = 882
item_pool = [f"item_{str(i).zfill(6)}" for i in range(1, NUM_ITEMS + 1)]

np.random.seed(42)
df['item_id'] = np.random.choice(item_pool, size=len(df), replace=True)

print(f"Unique items: {df['item_id'].nunique()}")
print(f"Avg transactions per item: {len(df) / df['item_id'].nunique():.1f}")
print(item_pool[:5])
# Out:
# Unique items: 882
# Avg transactions per item: 340.1
# ['item_000001', 'item_000002', 'item_000003', 'item_000004', 'item_000005']

# %%
# Verify strictly
assert df['item_id'].nunique() == NUM_ITEMS, f"Got {df['item_id'].nunique()} items, expected {NUM_ITEMS}"
print(f"Unique items: {df['item_id'].nunique()}")
# Out:
# Unique items: 882

# %%
df['item_id'].value_counts().describe()
# Out:
# count    882.000000
# mean     340.136054
# std       17.976264
# min      289.000000
# 25%      328.000000
# 50%      341.000000
# 75%      352.000000
# max      395.000000
# Name: item_id, dtype: float64

# %%
TOTAL_ROWS = len(df)

# Add date features
daily_df_temp = pd.DataFrame({
    'date': pd.date_range('2025-01-01', '2025-12-31')
})
num_days = len(daily_df_temp)
base = TOTAL_ROWS // num_days
remainder = TOTAL_ROWS % num_days

# Distribute the remainder across the days
tpd = np.full(num_days, base)
tpd[:remainder] += 1
daily_df_temp['transactions_per_day'] = tpd

expanded_dates = np.repeat(daily_df_temp['date'].values, daily_df_temp['transactions_per_day'].values)
df['date'] = expanded_dates

print(df[['date']].dtypes)
print(f"Shape after adding date: {df.shape}")
# Out:
# date    datetime64[ns]
# dtype: object
# Shape after adding date: (300000, 10)

# %% [markdown]
# ## Data encoding

# %%
from sklearn.preprocessing import LabelEncoder

df_encoded = df.copy()
encoder = LabelEncoder()

for col in df_encoded.columns:
    if df_encoded[col].dtype == 'object' and col != 'item_id':
        df_encoded[col] = encoder.fit_transform(df_encoded[col])

# Encode item_id separately to ensure consistent mapping
df_encoded['item_id'] = encoder.fit_transform(df_encoded['item_id'])
df_encoded = df_encoded.sort_values(by=['item_id', 'date']).reset_index(drop=True)

print(f"Unique item_ids: {df_encoded['item_id'].nunique()}")  # must be 822
print(df_encoded.head())
# Out:
# Unique item_ids: 882
#    item_id  purchase_count  view_count   price  stocks     sales  \
# 0        0              41         532  302145      54  12387945
# 1        0               8        3978  169674     160   1357392
# 2        0              14          52  394527      12   5523378
# 3        0               5        1021  129576     160    647880
# 4        0              18         400  114881     145   2067858
#
#    stock_value_retail  profit_status  conversion_rate       date
# 0            16315830              1         7.706767 2025-01-01
# 1            27147840              1         0.201106 2025-01-02
# 2             4734324              1        26.923077 2025-01-02
# 3            20732160              1         0.489716 2025-01-02
# 4            16657745              1         4.500000 2025-01-03

# %% [markdown]
# ## Feature engineering for transaction per day (prevent data leakage)

# %%
# Aggregate transactions to item-day level
df_agg = df_encoded.groupby(['item_id', 'date']).agg(
    purchase_count     = ('item_id', 'count'),
    view_count         = ('view_count', 'sum'),
    price              = ('price', 'mean'),
    stocks             = ('stocks', 'last'),
    sales              = ('sales', 'sum'),
    stock_value_retail = ('stock_value_retail', 'last'),
    profit_status      = ('profit_status', 'mean'),
    conversion_rate    = ('conversion_rate', 'mean')
).reset_index()

print(f"Unique items after agg: {df_agg['item_id'].nunique()}")  # 822
print(f"df_agg shape: {df_agg.shape}")
# Out:
# Unique items after agg: 882
# df_agg shape: (194885, 10)

# %%
# Every item must have every date (fill missing days with 0 activity)
full_dates = pd.date_range(df_agg['date'].min(), df_agg['date'].max(), freq='D')
all_items = df_agg['item_id'].unique()

# Create a index of all item-date combinations
idx = pd.MultiIndex.from_product([all_items, full_dates], names=['item_id', 'date'])
df_daily = df_agg.set_index(['item_id', 'date']).reindex(idx).reset_index()

# Days with no transactions -> 0 activity
zero_fill = [col for col in df_daily.columns if col not in ['item_id', 'date', 'stocks', 'stock_value_retail', 'price']]
forward_fill = ['price','stocks','stock_value_retail']

df_daily[zero_fill] = df_daily[zero_fill].fillna(0)
df_daily[forward_fill] = df_daily.groupby('item_id')[forward_fill].ffill().bfill()

print(f"df_daily shape: {df_daily.shape}")
# Out:
# df_daily shape: (321930, 10)

# %%
import gc
import psutil

def check_memory():
    ram = psutil.virtual_memory()
    print(f"Available RAM: {ram.available / (1024 ** 3):.2f} GB")
    print(f"Used RAM: {ram.percent}%")

check_memory()
# Out:
# Available RAM: 5.69 GB
# Used RAM: 64.4%

# %% [markdown]
# ## Time-Based Split & Split into train sales and profit

# %%
FEATURES = [col for col in df_encoded.columns if col not in ['profit_status', 'item_id', 'date', 'sales']]
TARGET_SALES = "sales"
TARGET_PROFIT = "profit_status"
LOOKBACK = 30

# Split by date before scaling to prevent data leakage
df_daily = df_daily.sort_values(by=['date', 'item_id']).reset_index(drop=True)
unique_dates = df_daily['date'].unique()
split_date = unique_dates[int(0.80 * len(unique_dates))] # Concern for division with integer to get split data wisely

df_train_raw = df_daily[df_daily['date'] <= split_date].copy()
df_test_raw = df_daily[df_daily['date'] > split_date].copy()

print(f"Train: {df_train_raw['date'].min()} -> {df_train_raw['date'].max()}")
print(f"Test: {df_test_raw['date'].min()} -> {df_test_raw['date'].max()}")
# Out:
# Train: 2025-01-01 00:00:00 -> 2025-10-20 00:00:00
# Test: 2025-10-21 00:00:00 -> 2025-12-31 00:00:00

# %% [markdown]
# # Data scaling using minmaxscaler
#
# df_train_raw  →  scale  →  df_train  →  sample  →  df_train_sampled  →  sequences
#                               ↑ delete raw            ↑ delete full           ↑ delete sampled
#                               here                    here                    here

# %%
# ============================================================
# CELL — Scale + Sample + Build Sequences (no del, memory safe)
# ============================================================
import gc
from sklearn.preprocessing import MinMaxScaler

scaler_X      = MinMaxScaler()
scaler_sales  = MinMaxScaler()
scaler_profit = MinMaxScaler()

# Step 1 — Downcast to float32 immediately to halve memory
def downcast_df(df):
    df = df.copy()
    for col in df.select_dtypes(include=['float64']).columns:
        df[col] = df[col].astype(np.float32)
    for col in df.select_dtypes(include=['int64']).columns:
        df[col] = df[col].astype(np.int32)
    return df

df_train_raw = downcast_df(df_train_raw)
df_test_raw  = downcast_df(df_test_raw)

print(f"Memory after downcast:")
print(f"  train: {df_train_raw.memory_usage(deep=True).sum() / 1e6:.1f} MB")
print(f"  test:  {df_test_raw.memory_usage(deep=True).sum() / 1e6:.1f} MB")

# Step 2 — Sample items BEFORE scaling to keep data small
MAX_ITEMS     = 300
sampled_items = df_train_raw['item_id'].unique()[:MAX_ITEMS]

df_train_raw = df_train_raw[df_train_raw['item_id'].isin(sampled_items)].reset_index(drop=True)
df_test_raw  = df_test_raw[df_test_raw['item_id'].isin(sampled_items)].reset_index(drop=True)

print(f"Sampled train shape: {df_train_raw.shape}")
print(f"Sampled test shape:  {df_test_raw.shape}")
print(f"Items used: {df_train_raw['item_id'].nunique()} / {MAX_ITEMS}")

# Step 3 — Scale in-place (overwrite same variable, no new copies)
df_train_raw[FEATURES]      = scaler_X.fit_transform(df_train_raw[FEATURES]).astype(np.float32)
df_train_raw[TARGET_SALES]  = np.log1p(
    scaler_sales.fit_transform(df_train_raw[[TARGET_SALES]])
).astype(np.float32)
df_train_raw[TARGET_PROFIT] = np.log1p(
    scaler_profit.fit_transform(df_train_raw[[TARGET_PROFIT]])
).astype(np.float32)

df_test_raw[FEATURES]       = scaler_X.transform(df_test_raw[FEATURES]).astype(np.float32)
df_test_raw[TARGET_SALES]   = np.log1p(
    scaler_sales.transform(df_test_raw[[TARGET_SALES]])
).astype(np.float32)
df_test_raw[TARGET_PROFIT]  = np.log1p(
    scaler_profit.transform(df_test_raw[[TARGET_PROFIT]])
).astype(np.float32)

# Rename for clarity (same object, no copy)
df_train = df_train_raw
df_test  = df_test_raw
gc.collect()

print(f"Memory after scaling:")
print(f"  train: {df_train.memory_usage(deep=True).sum() / 1e6:.1f} MB")
print(f"  test:  {df_test.memory_usage(deep=True).sum() / 1e6:.1f} MB")
# Out:
# Memory after downcast:
#   train: 13.4 MB
#   test:  3.3 MB
# Sampled train shape: (87900, 10)
# Sampled test shape:  (21600, 10)
# Items used: 300 / 300
# Memory after scaling:
#   train: 3.9 MB
#   test:  1.0 MB

# %% [markdown]
# ## LSTM Sequence Construction
#
# *  #### Construction data into range by columns chosen
# *  #### Prevent data leakage

# %%
def create_sequence(data, lookback=30):
    X, y_sales, y_profit = [], [], []
    for item_id, group in data.groupby('item_id'):
        group = group.sort_values('date').reset_index(drop=True)
        for i in range(len(group) - lookback):
            X.append(group[FEATURES].iloc[i:i+lookback].values)
            y_sales.append(group[TARGET_SALES].iloc[i+lookback])
            y_profit.append(group[TARGET_PROFIT].iloc[i+lookback])
    return (
        np.array(X,        dtype=np.float32),
        np.array(y_sales,  dtype=np.float32),
        np.array(y_profit, dtype=np.float32)
    )

X_train, y_sales_train, y_profit_train = create_sequence(df_train, lookback=LOOKBACK)
X_test,  y_sales_test,  y_profit_test  = create_sequence(df_test,  lookback=LOOKBACK)
gc.collect()

print(f"X_train shape:  {X_train.shape}")
print(f"X_test shape:   {X_test.shape}")
print(f"X_train memory: {X_train.nbytes / 1e6:.1f} MB")
print(f"X_test memory:  {X_test.nbytes / 1e6:.1f} MB")
# Out:
# X_train shape:  (78900, 30, 6)
# X_test shape:   (12600, 30, 6)
# X_train memory: 56.8 MB
# X_test memory:  9.1 MB

# %% [markdown]
# ## Build Multi-Output LSTM Model
#
# ### If no improvement in classification data with LSTM model
# * ### Try to use Machine learning models
#     * ### RandomForest Classifier
#     * ### DecisionTree Classifier
#     * ### Logistic Regression

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

timesteps = X_train.shape[1]
n_features = X_train.shape[2]

inputs = Input(shape=(timesteps, n_features))

x = LSTM(128, return_sequences=True)(inputs)
x = Dropout(0.2)(x)
x = LSTM(64, return_sequences=False)(x)
x = Dropout(0.2)(x)
x = Dense(32, activation='relu')(x)

sales_output = Dense(1, activation='linear', name='sales_output')(x)
profit_output = Dense(1, activation='sigmoid', name='profit_output')(x)

model = Model(inputs=inputs, outputs=[sales_output, profit_output])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss={
        'sales_output': 'mse',
        'profit_output': 'binary_crossentropy'
    },
    loss_weights={
        'sales_output': 1.0,
        'profit_output': 0.5
    },
    metrics={
        'sales_output': ['mae'],
        'profit_output': ['accuracy']
    }
)

model.summary()
# Out:
# 2026-03-05 15:47:18.977305: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2026-03-05 15:47:18.977341: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-03-05 15:47:18.977346: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-03-05 15:47:18.977666: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-05 15:47:18.977841: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30, 6)]              0         []
#
#  lstm (LSTM)                 (None, 30, 128)              69120     ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 30, 128)              0         ['lstm[0][0]']
#
#  lstm_1 (LSTM)               (None, 64)                   49408     ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 64)                   0         ['lstm_1[0][0]']
#
#  dense (Dense)               (None, 32)                   2080      ['dropout_1[0][0]']
#
#  sales_output (Dense)        (None, 1)                    33        ['dense[0][0]']
#
#  profit_output (Dense)       (None, 1)                    33        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 120674 (471.38 KB)
# Trainable params: 120674 (471.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model training

# %%
import gc
import tensorflow as tf

# ============================================================
# Ensure correct dtype + shape (float32 saves memory)
# ============================================================
y_sales_train  = y_sales_train.astype(np.float32).reshape(-1, 1)
y_sales_test   = y_sales_test.astype(np.float32).reshape(-1, 1)
y_profit_train = y_profit_train.astype(np.float32).reshape(-1, 1)
y_profit_test  = y_profit_test.astype(np.float32).reshape(-1, 1)
X_train        = X_train.astype(np.float32)
X_test         = X_test.astype(np.float32)

print(f"X_train memory: {X_train.nbytes / 1e6:.1f} MB")
print(f"X_test memory:  {X_test.nbytes / 1e6:.1f} MB")

# ============================================================
# Build tf.data pipelines
# ============================================================
BATCH_SIZE = 256  # larger = fewer steps = faster + less overhead

train_dataset = tf.data.Dataset.from_tensor_slices((
    X_train,
    {'sales_output': y_sales_train, 'profit_output': y_profit_train}
)).shuffle(buffer_size=5000, seed=42) \
  .batch(BATCH_SIZE) \
  .prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((
    X_test,
    {'sales_output': y_sales_test, 'profit_output': y_profit_test}
)).batch(BATCH_SIZE) \
  .prefetch(tf.data.AUTOTUNE)

gc.collect()

# ============================================================
# Callbacks
# ============================================================
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True,
    verbose=1
)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,   # halve LR when plateau hit
    patience=3,   # 3 not 10 — acts faster than early_stop
    min_lr=1e-6,
    verbose=1
)

# ============================================================
# Train
# ============================================================
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=20,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# X_train memory: 56.8 MB
# X_test memory:  9.1 MB
# Epoch 1/20
# 2026-03-05 15:47:20.988319: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2026-03-05 15:47:21.078547: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
# 309/309 [==============================] - 11s 29ms/step - loss: 0.3501 - sales_output_loss: 0.0080 - profit_output_loss: 0.6841 - sales_output_mae: 0.0628 - profit_output_accuracy: 0.3795 - val_loss: 0.3434 - val_sales_output_loss: 0.0038 - val_profit_output_loss: 0.6791 - val_sales_output_mae: 0.0423 - val_profit_output_accuracy: 0.4002 - lr: 0.0010
# Epoch 2/20
# 309/309 [==============================] - 8s 25ms/step - loss: 0.3421 - sales_output_loss: 0.0037 - profit_output_loss: 0.6768 - sales_output_mae: 0.0447 - profit_output_accuracy: 0.4071 - val_loss: 0.3424 - val_sales_output_loss: 0.0037 - val_profit_output_loss: 0.6773 - val_sales_output_mae: 0.0438 - val_profit_output_accuracy: 0.4002 - lr: 0.0010
# Epoch 3/20
# 309/309 [==============================] - 8s 26ms/step - loss: 0.3420 - sales_output_loss: 0.0038 - profit_output_loss: 0.6764 - sales_output_mae: 0.0453 - profit_output_accuracy: 0.4073 - val_loss: 0.3425 - val_sales_output_loss: 0.0039 - val_profit_output_loss: 0.6773 - val_sales_output_mae: 0.0416 - val_profit_output_accuracy: 0.4002 - lr: 0.0010
# Epoch 4/20
# 309/309 [==============================] - 8s 26ms/step - loss: 0.3417 - sales_output_loss: 0.0037 - profit_output_loss: 0.6760 - sales_output_mae: 0.0448 - profit_output_accuracy: 0.4073 - val_loss: 0.3424 - val_sales_output_loss: 0.0038 - val_profit_output_loss: 0.6772 - val_sales_output_mae: 0.0425 - val_profit_output_accuracy: 0.4002 - lr: 0.0010
# Epoch 5/20
# 306/309 [============================>.] - ETA: 0s - loss: 0.3417 - sales_output_loss: 0.0037 - profit_output_loss: 0.6761 - sales_output_mae: 0.0447 - profit_output_accuracy: 0.4072Restoring model weights from the end of the best epoch: 2.
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 309/309 [==============================] - 8s 26ms/step - loss: 0.3417 - sales_output_loss: 0.0037 - profit_output_loss: 0.6761 - sales_output_mae: 0.0446 - profit_output_accuracy: 0.4073 - val_loss: 0.3426 - val_sales_output_loss: 0.0039 - val_profit_output_loss: 0.6773 - val_sales_output_mae: 0.0415 - val_profit_output_accuracy: 0.4002 - lr: 0.0010
# Epoch 5: early stopping

# %% [markdown]
# ## Prediction with model

# %%
# ============================================================
# CELL 1 — Evaluate on Test Set
# ============================================================
# Predict on test dataset (use dataset not raw array)
sales_pred, profit_pred = model.predict(test_dataset, verbose=1)

# Inverse log1p then inverse scale
sales_pred_inv  = scaler_sales.inverse_transform(np.expm1(sales_pred))
profit_pred_inv = (profit_pred > 0.5).astype(int)

print("Predicted sales (first 10):")
print(np.round(sales_pred_inv[:10].flatten(), 2))
print("\nPredicted profit (first 10):")
print(pd.Series(profit_pred_inv[:10].flatten()).map({0: 'loss', 1: 'profit'}).values)

df_results = pd.DataFrame({
    'predicted_sales':  np.round(sales_pred_inv.flatten(), 2),
    'predicted_profit': pd.Series(profit_pred_inv.flatten()).map({0: 'loss', 1: 'profit'})
})
print(f"\ndf_results shape: {df_results.shape}")
df_results.head(10)
# Out:
# 50/50 [==============================] - 1s 11ms/step
# Predicted sales (first 10):
# [6618337.5 6612167.5 6612352.5 6612222.5 6612081.5 6609728.5 6608742.
#  6618337.5 6617329.5 6617785. ]
#
# Predicted profit (first 10):
# ['loss' 'loss' 'loss' 'loss' 'loss' 'loss' 'loss' 'loss' 'loss' 'loss']
#
# df_results shape: (12600, 2)
#    predicted_sales predicted_profit
# 0        6618337.5             loss
# 1        6612167.5             loss
# 2        6612352.5             loss
# 3        6612222.5             loss
# 4        6612081.5             loss
# 5        6609728.5             loss
# 6        6608742.0             loss
# 7        6618337.5             loss
# 8        6617329.5             loss
# 9        6617785.0             loss

# %% [markdown]
# ## Model prediction testing

# %%
# ============================================================
# CELL 2 — Predict All Sampled Items
# ============================================================
df_pred = df_daily[df_daily['item_id'].isin(sampled_items)].copy()
df_pred = df_pred.sort_values(['item_id', 'date']).reset_index(drop=True)

# Scale features only (no target scaling needed for prediction input)
df_pred[FEATURES] = scaler_X.transform(df_pred[FEATURES]).astype(np.float32)

# Build sequences + track metadata
X_all, item_ids_all, dates_all = [], [], []

for item_id, group in df_pred.groupby('item_id'):
    group = group.sort_values('date').reset_index(drop=True)
    if len(group) <= LOOKBACK:
        continue
    for i in range(len(group) - LOOKBACK):
        X_all.append(group[FEATURES].iloc[i:i+LOOKBACK].values)
        item_ids_all.append(item_id)
        dates_all.append(group['date'].iloc[i + LOOKBACK])

X_all = np.array(X_all, dtype=np.float32)
print(f"X_all shape: {X_all.shape}")

# Predict in batches
sales_pred_all, profit_pred_all = model.predict(X_all, batch_size=512, verbose=1)

# Inverse transform — undo log1p then undo scaler
sales_inv    = scaler_sales.inverse_transform(np.expm1(sales_pred_all)).flatten()
profit_class = (profit_pred_all > 0.5).astype(int).flatten()

df_result = pd.DataFrame({
    'item_id'          : item_ids_all,   # still encoded int, decoded in cell 3
    'date'             : dates_all,
    'predicted_sales'  : np.round(sales_inv, 2),
    'predicted_profit' : pd.Series(profit_class).map({0: 'loss', 1: 'profit'})
})

gc.collect()
print(f"df_result shape: {df_result.shape}")
df_result.sort_values(['date', 'item_id']).reset_index(drop=True).head()
# Out:
# X_all shape: (100500, 30, 6)
# 197/197 [==============================] - 2s 9ms/step
# df_result shape: (100500, 4)
#    item_id       date  predicted_sales predicted_profit
# 0        0 2025-01-31        6610704.0             loss
# 1        1 2025-01-31        6617958.0             loss
# 2        2 2025-01-31        6616397.0             loss
# 3        3 2025-01-31        6615930.0             loss
# 4        4 2025-01-31        6612038.0             loss

# %%
# Create a mapping dictionary from original df
item_id_mapping = dict(zip(
    df_encoded['item_id'].astype(int),
    df['item_id'].values
))

# item_id already mapped to string in df_result, no need to re-map
df_result_new = df_result.copy()
df_result_new = df_result_new.sort_values(by='date', ascending=True).reset_index(drop=True)

print("Updated item_ids sample:")
print(df_result_new['item_id'].head())
df_result_new
# Out:
# Updated item_ids sample:
# 0      0
# 1    209
# 2    208
# 3    207
# 4    206
# Name: item_id, dtype: int64
#         item_id       date  predicted_sales predicted_profit
# 0             0 2025-01-31        6610704.0             loss
# 1           209 2025-01-31        6614554.0             loss
# 2           208 2025-01-31        6613144.5             loss
# 3           207 2025-01-31        6610781.0             loss
# 4           206 2025-01-31        6613393.5             loss
# ...         ...        ...              ...              ...
# 100495      200 2025-12-31        6614618.0             loss
# 100496      201 2025-12-31        6612428.0             loss
# 100497      202 2025-12-31        6611181.5             loss
# 100498      204 2025-12-31        6615746.0             loss
# 100499      299 2025-12-31        6615193.0             loss
#
# [100500 rows x 4 columns]

# %% [markdown]
# ## Decode item_id back to original string labels

# %%
# ============================================================
# CELL 3 — Decode item_id back to original string labels
# ============================================================
# Build mapping: encoded int → original string item_id
item_id_mapping = dict(zip(
    df_encoded['item_id'].astype(int),
    df['item_id'].values
))

df_result['item_id'] = df_result['item_id'].map(item_id_mapping)

# Verify mapping worked
null_ids = df_result['item_id'].isna().sum()
print(f"Unmapped item_ids: {null_ids}")  # should be 0
print(f"Sample item_ids: {df_result['item_id'].unique()[:5]}")

df_result = df_result.sort_values('date').reset_index(drop=True)
print(f"df_result shape: {df_result.shape}")
df_result.head()
# Out:
# Unmapped item_ids: 0
# Sample item_ids: ['item_000820' 'item_000676' 'item_000435' 'item_000196' 'item_000363']
# df_result shape: (100500, 4)
#        item_id       date  predicted_sales predicted_profit
# 0  item_000820 2025-01-31        6610704.0             loss
# 1  item_000393 2025-01-31        6614554.0             loss
# 2  item_000077 2025-01-31        6613144.5             loss
# 3  item_000587 2025-01-31        6610781.0             loss
# 4  item_000323 2025-01-31        6613393.5             loss

# %% [markdown]
# ## Merge df_result wuth df_daily
#
# * ### Recheck data first (especially in **Data scaling**) before ensure for data result reporting

# %%
# ============================================================
# CELL 4 — Merge Predictions with df_daily
# ============================================================
# Decode item_id in df_daily for sampled items only
df_daily_decoded = df_daily[df_daily['item_id'].isin(sampled_items)].copy()
df_daily_decoded['item_id'] = df_daily_decoded['item_id'].map(item_id_mapping)

# Merge on item_id + date
df_merged = df_daily_decoded.merge(
    df_result[['item_id', 'date', 'predicted_sales', 'predicted_profit']],
    on=['item_id', 'date'],
    how='left'
)
df_merged = df_merged.sort_values(['item_id', 'date']).reset_index(drop=True)

# First LOOKBACK days per item won't have predictions — expected
null_count = df_merged['predicted_sales'].isna().sum()
print(f"Null predictions: {null_count} rows (expected ~{len(sampled_items) * LOOKBACK})")

df_merged = df_merged.dropna(subset=['predicted_sales', 'predicted_profit']).reset_index(drop=True)
print(f"Shape after dropping nulls: {df_merged.shape}")
df_merged
# Out:
# Null predictions: 9000 rows (expected ~9000)
# Shape after dropping nulls: (136680, 12)
#             item_id       date  purchase_count  view_count     price  stocks  \
# 0       item_000003 2025-01-31             1.0       876.0  332377.0    84.0
# 1       item_000003 2025-02-01             1.0       302.0  307672.0   111.0
# 2       item_000003 2025-02-02             0.0         0.0  307672.0   111.0
# 3       item_000003 2025-02-03             0.0         0.0  307672.0   111.0
# 4       item_000003 2025-02-04             0.0         0.0  307672.0   111.0
# ...             ...        ...             ...         ...       ...     ...
# 136675  item_000882 2025-12-27             1.0       402.0  298581.0    70.0
# 136676  item_000882 2025-12-28             2.0      1999.0  271015.5    40.0
# 136677  item_000882 2025-12-29             0.0         0.0  271015.5    40.0
# 136678  item_000882 2025-12-30             0.0         0.0  271015.5    40.0
# 136679  item_000882 2025-12-31             0.0         0.0  271015.5    40.0
#
#              sales  stock_value_retail  profit_status  conversion_rate  \
# 0       11965572.0          27919668.0            1.0         4.109589
# 1         307672.0          34151592.0            1.0         0.331126
# 2              0.0          34151592.0            0.0         0.000000
# 3              0.0          34151592.0            0.0         0.000000
# 4              0.0          34151592.0            0.0         0.000000
# ...            ...                 ...            ...              ...
# 136675   1791486.0          20900670.0            1.0         1.492537
# 136676  13405308.0           9245040.0            0.5         1.659039
# 136677         0.0           9245040.0            0.0         0.000000
# 136678         0.0           9245040.0            0.0         0.000000
# 136679         0.0           9245040.0            0.0         0.000000
#
#         predicted_sales predicted_profit
# 0             6612146.5             loss
# 1             6615811.0             loss
# 2             6615540.5             loss
# 3             6615876.0             loss
# 4             6615920.0             loss
# ...                 ...              ...
# 136675        6616624.5             loss
# 136676        6617134.0             loss
# 136677        6617459.0             loss
# 136678        6619043.0             loss
# 136679        6619270.0             loss
#
# [136680 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Aggregate all sources by date
agg_sales       = df_agg.groupby('date')['sales'].sum().reset_index()
daily_sales     = df_daily.groupby('date')['sales'].sum().reset_index()
df_sales        = df.groupby('date')['sales'].sum().reset_index()
merged_sales    = df_merged.groupby('date')['predicted_sales'].sum().reset_index()

# Sample every 7 days to keep bars readable
agg_sales       = agg_sales.iloc[::7]
daily_sales     = daily_sales.iloc[::7]
df_sales        = df_sales.iloc[::7]
merged_sales    = merged_sales.iloc[::7]

fig, axes = plt.subplots(2, 2, figsize=(16, 10), sharey=False)
fig.suptitle('Total Sales Comparison Across DataFrames', fontsize=16, fontweight='bold', y=1.02)

plots = [
    (axes[0, 0], agg_sales,    'date', 'sales',           '#4C72B0', 'df_agg Sales'),
    (axes[0, 1], daily_sales,  'date', 'sales',           '#DD8452', 'df_daily Sales'),
    (axes[1, 0], df_sales,     'date', 'sales',           '#55A868', 'df Sales'),
    (axes[1, 1], merged_sales, 'date', 'predicted_sales', '#C44E52', 'df_merged Predicted Sales'),
]

for ax, data, x_col, y_col, color, title in plots:
    ax.bar(data[x_col], data[y_col], color=color, alpha=0.85, width=5)
    ax.set_title(title, fontsize=13, fontweight='bold')
    ax.set_xlabel('Date', fontsize=10)
    ax.set_ylabel('Total Sales', fontsize=10)
    ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
    ax.tick_params(axis='x', rotation=45)
    # Add mean line
    mean_val = data[y_col].mean()
    ax.axhline(mean_val, color='black', linestyle='--', linewidth=1, label=f'Mean: {mean_val:,.0f}')
    ax.legend(fontsize=9)
    ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()
