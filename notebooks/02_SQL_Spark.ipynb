# %% [markdown]
# ## Insert Spark dataframe into a SQL table

# %%
# !pip show pyspark
# Out:
# Name: pyspark
# Version: 3.5.1
# Summary: Apache Spark Python API
# Home-page: https://github.com/apache/spark/tree/master/python
# Author: Spark Developers
# Author-email: dev@spark.apache.org
# License: http://www.apache.org/licenses/LICENSE-2.0
# Location: /Users/miftahhadiyannoor/Documents/Fashion_Recommendation_Engineer/.venv/lib/python3.11/site-packages
# Requires: py4j
# Required-by: apache-airflow-providers-apache-spark

# %%
import os
os.environ["JAVA_HOME"] = "/opt/homebrew/opt/openjdk@17"
# No findspark needed!

from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("Fashion-SQL")
    .master("local[*]")
    .config("spark.sql.shuffle.partitions", "8")
    .config("spark.driver.memory", "4g")
    .getOrCreate()
)
# Out:
# 26/03/02 01:12:25 WARN Utils: Your hostname, MacBook-Air-M4.local resolves to a loopback address: 127.0.0.1; using 172.20.10.3 instead (on interface en0)
# 26/03/02 01:12:25 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/02 01:12:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
sql = spark.read.parquet("spark-warehouse/fashion_sql_datasets")
# sql.createOrReplaceTempView("fashion_sql_datasets")

spark.sql(
    """
SELECT * FROM fashion_sql_datasets;
"""
).show()

print(f"Total rows:", spark.sql("SELECT * FROM fashion_sql_datasets").count())
# Out:
# +----------+--------+---------------+-----------+----------+---------+--------+---------------+----------+--------------+----------+-----------+--------------+---------+------+------+
# |   item_id|category|    subcategory|sleeve_type|    season|   fabric|occasion|formality_level|size_range|         brand|view_count|click_count|purchase_count|length_cm| price|stocks|
# +----------+--------+---------------+-----------+----------+---------+--------+---------------+----------+--------------+----------+-----------+--------------+---------+------+------+
# |TNC_000001| bottoms|     men_cargos|       long|    winter|polyester|  casual|           high|         S|Tommy Hilfiger|        93|        192|             4|       97|262476|    35|
# |TNC_000002|    tops|  formal_shirts|       long|    winter|    linen|   party|         medium|         S|           HnM|      2941|         84|             5|       77|266987|   182|
# ...

# %%
df = spark.read.parquet("spark-warehouse/fashion_sql_datasets")
df.show(100)
# Out:
# +----------+--------+---------------+-----------+----------+---------+--------+---------------+----------+--------------+----------+-----------+--------------+---------+------+------+
# |   item_id|category|    subcategory|sleeve_type|    season|   fabric|occasion|formality_level|size_range|         brand|view_count|click_count|purchase_count|length_cm| price|stocks|
# +----------+--------+---------------+-----------+----------+---------+--------+---------------+----------+--------------+----------+-----------+--------------+---------+------+------+
# |TNC_000001| bottoms|     men_cargos|       long|    winter|polyester|  casual|           high|         S|Tommy Hilfiger|        93|        192|             4|       97|262476|    35|
# |TNC_000002|    tops|  formal_shirts|       long|    winter|    linen|   party|         medium|         S|           HnM|      2941|         84|             5|       77|266987|   182|
# ...

# %%
import sqlalchemy
import pandas as pd
from sqlalchemy import create_engine, engine
import psycopg2
from sqlalchemy.engine import create

CONNECTION_STRING = "postgresql+psycopg2://airflow:dianhinhin123@localhost:5432/airflow"

# Check connection in sqlalchemy is it exists or not
try:
    engine = create_engine(CONNECTION_STRING)
    with engine.connect() as conn:
        print(f"Connection is exists in: {conn}")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Connection is exists in: <sqlalchemy.engine.base.Connection object at 0x1346e6e10>
