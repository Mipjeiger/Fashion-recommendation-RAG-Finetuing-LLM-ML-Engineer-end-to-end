# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("Fashion-Recommender-Engineer")
    .master("local[*]")
    .config("spark.sql.shuffle.partitions", "8")
    .config("spark.driver.memory", "4g")
    .getOrCreate()
)
# Out:
# 26/02/10 19:46:50 WARN Utils: Your hostname, MacBook-Air-M4.local resolves to a loopback address: 127.0.0.1; using 192.168.100.12 instead (on interface en0)
# 26/02/10 19:46:50 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/10 19:46:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Verify spark
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.100.12:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Fashion-Recommender-Engineer</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Load CSV dataset into Spark DataFrame

# %%
CSV_PATH = "../data/fashion_datasets.csv"

df = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .csv(CSV_PATH)
)
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- item_id: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- subcategory: string (nullable = true)
#  |-- sleeve_type: string (nullable = true)
#  |-- season: string (nullable = true)
#  |-- fabric: string (nullable = true)
#  |-- occasion: string (nullable = true)
#  |-- formality_level: string (nullable = true)
#  |-- size_range: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- view_count: integer (nullable = true)
#  |-- click_count: integer (nullable = true)
#  |-- purchase_count: integer (nullable = true)
#  |-- length_cm: integer (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- stocks: integer (nullable = true)

# %% [markdown]
# ## Convert Spark DataFrame → Pandas DataFrame

# %%
df = df.drop("_c0")

# Select & reorder columns
columns = [
    "item_id",
    "category",
    "subcategory",
    "sleeve_type",
    "season",
    "fabric",
    "occasion",
    "formality_level",
    "size_range",
    "brand",
    "view_count",
    "click_count",
    "purchase_count",
    "length_cm",
    "price",
    "stocks",
]

df = df.select(columns)

# %%
# Convert Spark -> Dataframe
df_cleaned = df.toPandas()
print(type(df_cleaned))
df_cleaned
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             item_id category      subcategory sleeve_type      season  \
# 0        TNC_000003     tops  printed_tshirts       short      summer
# 1        TNC_000004     tops    formal_shirts        long      summer
# 2        TNC_000006     tops    formal_shirts        long      summer
# 3        TNC_000007     tops    solid_tshirts       short  all-season
# 4        TNC_000008     tops    casual_shirts        long      winter
# ...             ...      ...              ...         ...         ...
# 550270  TNC_1099992     tops  printed_tshirts       short  all-season
# 550271  TNC_1099993     tops    formal_shirts        long      summer
# 550272  TNC_1099995     tops    casual_shirts        long      winter
# 550273  TNC_1099996     tops  printed_tshirts       short      summer
# 550274  TNC_1099999     tops    casual_shirts        long      summer
#
#            fabric occasion formality_level size_range           brand  \
# 0       polyester   casual             low          L            Nike
# 1           denim    party             low          M            ZARA
# 2          cotton   casual          medium          S            Nike
# 3          fleece   casual            high         XS  Tommy Hilfiger
# 4           linen   office          medium          S            Polo
# ...           ...      ...             ...        ...             ...
# 550270  polyester   casual             low          M            Polo
# 550271      linen   office             low          L            Polo
# 550272     fleece   casual          medium         XL             HnM
# 550273     cotton   office             low          M             HnM
# 550274      linen   office            high          L             HnM
#
#         view_count  click_count  purchase_count  length_cm   price  stocks
# 0             2411          787              42         65  157055     146
# 1             1219           10              21         68  282021     115
# 2             1209           21              27         71  315906       0
# 3              257          146               8         73  105185     151
# 4              401          322              23         78  209024     112
# ...            ...          ...             ...        ...     ...     ...
# 550270          55            9              17         70  160868      95
# 550271         136          261               6         73  302436     196
# 550272         512          328              21         78  276939     100
# 550273         165          242               5         72  122545      73
# 550274         651          231              19         77  155882     175
#
# [550275 rows x 16 columns]

# %% [markdown]
# ## Insert Spark DataFrame into a Table

# %%
spark_sql = (
    SparkSession.builder
    .appName("fashion-recommender")
    .enableHiveSupport()
    .getOrCreate()
)
df.write.mode("overwrite").saveAsTable("fashion_sql")
# Out:
# 26/02/10 19:47:08 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
spark.sql("SELECT * FROM fashion_sql").show()
# Out:
# +----------+--------+---------------+-----------+----------+---------+--------+---------------+----------+--------------+----------+-----------+--------------+---------+------+------+
# |   item_id|category|    subcategory|sleeve_type|    season|   fabric|occasion|formality_level|size_range|         brand|view_count|click_count|purchase_count|length_cm| price|stocks|
# +----------+--------+---------------+-----------+----------+---------+--------+---------------+----------+--------------+----------+-----------+--------------+---------+------+------+
# |TNC_000003|    tops|printed_tshirts|      short|    summer|polyester|  casual|            low|         L|          Nike|      2411|        787|            42|       65|157055|   146|
# |TNC_000004|    tops|  formal_shirts|       long|    summer|    denim|   party|            low|         M|          ZARA|      1219|         10|            21|       68|282021|   115|
# |TNC_000006|    tops|  formal_shirts|       long|    summer|   cotton|  casual|         medium|         S|          Nike|      1209|         21|            27|       71|315906|     0|
# |TNC_000007|    tops|  solid_tshirts|      short|all-season|   fleece|  casual|           high|        XS|Tommy Hilfiger|       257|        146|             8|       73|105185|   151|
# |TNC_000008|    tops|  casual_shirts|       long|    winter|    linen|  office|         medium|         S|          Polo|       401|        322|            23|       78|209024|   112|
# |TNC_000010|    tops|printed_hoodies|       long|    winter|polyester|  office|         medium|         M|Tommy Hilfiger|       110|         64|            20|       77|251354|    61|
# |TNC_000013|    tops|  formal_shirts|       long|    winter|polyester|  casual|           high|         M|        Adidas|       953|         80|            22|       77|267128|   194|
# |TNC_000014|    tops|  formal_shirts|       long|    winter|    denim|  office|            low|         S|          ZARA|       144|         29|            12|       74|268636|   109|
# |TNC_000015|    tops|  solid_tshirts|      short|all-season|    linen|   party|           high|       XXL|Tommy Hilfiger|       424|         19|            65|       70|142864|    13|
# |TNC_000016|    tops|  solid_tshirts|      short|all-season|    linen|  office|            low|       XXL|           HnM|       587|        236|            17|       68|166760|    15|
# |TNC_000017|    tops|  casual_shirts|       long|all-season|polyester|  casual|         medium|         M|           HnM|      2082|         31|            20|       76|204018|    40|
# |TNC_000018|    tops|printed_hoodies|       long|all-season|   fleece|  casual|            low|         M|          Polo|       308|        131|           103|       74|304136|   104|
# |TNC_000019|    tops|  formal_shirts|       long|all-season|    linen|  casual|            low|        XS|          Nike|       795|        166|            12|       76|331956|    72|
# |TNC_000020|    tops|printed_tshirts|      short|all-season|   cotton|   party|            low|         S|        Adidas|      1389|        155|            58|       65|122189|   150|
# |TNC_000021|    tops|printed_hoodies|       long|all-season|   cotton|  office|         medium|        XS|          Polo|       399|        125|            29|       73|342886|   185|
# |TNC_000022|    tops|printed_hoodies|       long|    summer|    linen|  office|            low|         S|        Adidas|      1034|         91|             2|       72|255731|   191|
# |TNC_000024|    tops|  solid_tshirts|      short|    summer|   cotton|  casual|            low|         M|        Adidas|       401|         45|             0|       74|160610|    27|
# |TNC_000028|    tops|  formal_shirts|       long|    summer|    linen|  casual|            low|         L|          ZARA|       800|          9|            43|       73|269282|    50|
# |TNC_000029|    tops|printed_tshirts|      short|    winter|polyester|  casual|            low|         L|          Polo|      1537|         64|            38|       74|116368|    14|
# |TNC_000034|    tops|  solid_tshirts|      short|all-season|   cotton|  office|            low|         M|          ZARA|      1817|         67|            34|       71|104500|   110|
# +----------+--------+---------------+-----------+----------+---------+--------+---------------+----------+--------------+----------+-----------+--------------+---------+------+------+
# only showing top 20 rows

# %%
df.write.mode("overwrite").parquet("hdfs/fashion_items_parquet")
