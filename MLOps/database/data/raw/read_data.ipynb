# %%
import pandas as pd

pd.read_parquet("matched_fashion_dataset_300k_rows.parquet")
# Out:
#            item_id category      subcategory sleeve_type      season  \
# 0       TNC_000001     tops    formal_shirts        long  all-season
# 1       TNC_000002     tops    casual_shirts        long      summer
# 2       TNC_000003  bottoms            jeans        long      winter
# 3       TNC_000004  bottoms            jeans        long      summer
# 4       TNC_000005     tops    casual_shirts        long      winter
# ...            ...      ...              ...         ...         ...
# 299995  TNC_299996     tops    casual_shirts        long      winter
# 299996  TNC_299997  bottoms       men_cargos        long      summer
# 299997  TNC_299998  bottoms            jeans        long      summer
# 299998  TNC_299999     tops  printed_hoodies        long      summer
# 299999  TNC_300000  bottoms            jeans        long      winter
#
#            fabric occasion formality_level size_range           brand  \
# ...

# %%
pd.read_parquet("matched_fashion_balance_rows_prediction.parquet")
# Out:
#             item_id       date  purchase_count  view_count     price  stocks  \
# 0       item_000001 2025-01-31             3.0      3736.0  346555.0   172.0
# 1       item_000001 2025-02-01             3.0       356.0  216545.0    96.0
# 2       item_000001 2025-02-02             0.0         0.0  216545.0    96.0
# 3       item_000001 2025-02-03             2.0      1044.0  284314.0    49.0
# 4       item_000001 2025-02-04             2.0      1104.0  285865.0   148.0
# ...             ...        ...             ...         ...       ...     ...
# 298145  item_000890 2025-12-27             0.0         0.0  305113.5   183.0
# 298146  item_000890 2025-12-28             1.0       361.0  347344.0    58.0
# 298147  item_000890 2025-12-29             2.0      1571.0  204049.5    68.0
# 298148  item_000890 2025-12-30             0.0         0.0  204049.5    68.0
# 298149  item_000890 2025-12-31             0.0         0.0  204049.5    68.0
#
# ...
